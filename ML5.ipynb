# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2022-03-01 08:43:30--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2022-03-01 08:43:31--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   268MB/s    in 0.2s
#
# 2022-03-01 08:43:31 (268 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Knight', 'King', 'Rook', 'Pawn', 'Queen', 'Bishop']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 37s - loss: 1.8769 - accuracy: 0.1643 - val_loss: 1.7894 - val_accuracy: 0.1923 - 37s/epoch - 591ms/step
# Epoch 2/50
# 63/63 - 35s - loss: 1.7916 - accuracy: 0.1944 - val_loss: 1.7845 - val_accuracy: 0.1923 - 35s/epoch - 562ms/step
# Epoch 3/50
# 63/63 - 35s - loss: 1.7884 - accuracy: 0.1764 - val_loss: 1.7819 - val_accuracy: 0.1923 - 35s/epoch - 557ms/step
# Epoch 4/50
# 63/63 - 35s - loss: 1.7895 - accuracy: 0.1864 - val_loss: 1.7818 - val_accuracy: 0.1923 - 35s/epoch - 558ms/step
# Epoch 5/50
# 63/63 - 35s - loss: 1.7847 - accuracy: 0.1924 - val_loss: 1.7811 - val_accuracy: 0.1923 - 35s/epoch - 558ms/step
# Epoch 6/50
# 63/63 - 35s - loss: 1.7845 - accuracy: 0.1924 - val_loss: 1.7802 - val_accuracy: 0.1923 - 35s/epoch - 554ms/step
# Epoch 7/50
# 63/63 - 35s - loss: 1.7878 - accuracy: 0.1924 - val_loss: 1.7783 - val_accuracy: 0.1923 - 35s/epoch - 555ms/step
# Epoch 8/50
# 63/63 - 35s - loss: 1.7779 - accuracy: 0.1964 - val_loss: 1.7752 - val_accuracy: 0.1923 - 35s/epoch - 558ms/step
# Epoch 9/50
# 63/63 - 35s - loss: 1.7511 - accuracy: 0.2385 - val_loss: 1.7654 - val_accuracy: 0.1923 - 35s/epoch - 561ms/step
# Epoch 10/50
# 63/63 - 35s - loss: 1.7318 - accuracy: 0.2465 - val_loss: 1.7262 - val_accuracy: 0.2500 - 35s/epoch - 557ms/step
# Epoch 11/50
# 63/63 - 35s - loss: 1.7203 - accuracy: 0.2826 - val_loss: 1.8040 - val_accuracy: 0.1923 - 35s/epoch - 558ms/step
# Epoch 12/50
# 63/63 - 35s - loss: 1.7226 - accuracy: 0.2986 - val_loss: 1.6791 - val_accuracy: 0.2885 - 35s/epoch - 558ms/step
# Epoch 13/50
# 63/63 - 35s - loss: 1.6819 - accuracy: 0.3026 - val_loss: 1.7442 - val_accuracy: 0.3269 - 35s/epoch - 558ms/step
# Epoch 14/50
# 63/63 - 35s - loss: 1.6429 - accuracy: 0.3126 - val_loss: 1.5849 - val_accuracy: 0.3846 - 35s/epoch - 558ms/step
# Epoch 15/50
# 63/63 - 35s - loss: 1.5469 - accuracy: 0.3808 - val_loss: 1.6335 - val_accuracy: 0.3846 - 35s/epoch - 557ms/step
# Epoch 16/50
# 63/63 - 35s - loss: 1.5252 - accuracy: 0.3788 - val_loss: 1.6355 - val_accuracy: 0.3077 - 35s/epoch - 558ms/step
# Epoch 17/50
# 63/63 - 35s - loss: 1.4675 - accuracy: 0.4188 - val_loss: 1.5372 - val_accuracy: 0.3654 - 35s/epoch - 559ms/step
# Epoch 18/50
# 63/63 - 35s - loss: 1.4224 - accuracy: 0.4649 - val_loss: 1.4651 - val_accuracy: 0.4038 - 35s/epoch - 555ms/step
# Epoch 19/50
# 63/63 - 35s - loss: 1.3773 - accuracy: 0.4549 - val_loss: 1.6416 - val_accuracy: 0.3269 - 35s/epoch - 552ms/step
# Epoch 20/50
# 63/63 - 35s - loss: 1.3283 - accuracy: 0.4709 - val_loss: 1.4872 - val_accuracy: 0.4231 - 35s/epoch - 554ms/step
# Epoch 21/50
# 63/63 - 35s - loss: 1.2964 - accuracy: 0.5210 - val_loss: 1.5757 - val_accuracy: 0.3462 - 35s/epoch - 552ms/step
# Epoch 22/50
# 63/63 - 35s - loss: 1.2475 - accuracy: 0.5291 - val_loss: 1.6805 - val_accuracy: 0.3269 - 35s/epoch - 552ms/step
# Epoch 23/50
# 63/63 - 35s - loss: 1.2235 - accuracy: 0.5190 - val_loss: 1.3650 - val_accuracy: 0.4615 - 35s/epoch - 551ms/step
# Epoch 24/50
# 63/63 - 35s - loss: 1.1940 - accuracy: 0.5631 - val_loss: 1.4585 - val_accuracy: 0.4615 - 35s/epoch - 555ms/step
# Epoch 25/50
# 63/63 - 35s - loss: 1.1207 - accuracy: 0.5932 - val_loss: 1.5104 - val_accuracy: 0.4423 - 35s/epoch - 562ms/step
# Epoch 26/50
# 63/63 - 36s - loss: 1.0120 - accuracy: 0.6232 - val_loss: 1.3422 - val_accuracy: 0.5192 - 36s/epoch - 565ms/step
# Epoch 27/50
# 63/63 - 36s - loss: 1.0911 - accuracy: 0.5892 - val_loss: 1.6488 - val_accuracy: 0.4231 - 36s/epoch - 564ms/step
# Epoch 28/50
# 63/63 - 36s - loss: 1.0723 - accuracy: 0.6152 - val_loss: 1.4155 - val_accuracy: 0.4423 - 36s/epoch - 564ms/step
# Epoch 29/50
# 63/63 - 36s - loss: 1.0020 - accuracy: 0.6353 - val_loss: 1.3779 - val_accuracy: 0.4423 - 36s/epoch - 566ms/step
# Epoch 30/50
# 63/63 - 35s - loss: 0.9821 - accuracy: 0.6373 - val_loss: 1.3020 - val_accuracy: 0.4423 - 35s/epoch - 559ms/step
# Epoch 31/50
# 63/63 - 35s - loss: 0.9691 - accuracy: 0.6413 - val_loss: 1.3416 - val_accuracy: 0.4615 - 35s/epoch - 558ms/step
# Epoch 32/50
# 63/63 - 35s - loss: 0.9062 - accuracy: 0.6433 - val_loss: 1.3170 - val_accuracy: 0.4615 - 35s/epoch - 560ms/step
# Epoch 33/50
# 63/63 - 35s - loss: 0.8566 - accuracy: 0.6974 - val_loss: 1.5349 - val_accuracy: 0.4423 - 35s/epoch - 559ms/step
# Epoch 34/50
# 63/63 - 35s - loss: 0.7635 - accuracy: 0.7194 - val_loss: 1.4230 - val_accuracy: 0.4423 - 35s/epoch - 558ms/step
# Epoch 35/50
# 63/63 - 35s - loss: 0.7740 - accuracy: 0.7194 - val_loss: 1.2631 - val_accuracy: 0.4808 - 35s/epoch - 559ms/step
# Epoch 36/50
# 63/63 - 35s - loss: 0.7379 - accuracy: 0.7134 - val_loss: 1.5970 - val_accuracy: 0.3846 - 35s/epoch - 562ms/step
# Epoch 37/50
# 63/63 - 36s - loss: 0.7243 - accuracy: 0.7635 - val_loss: 1.7284 - val_accuracy: 0.3462 - 36s/epoch - 564ms/step
# Epoch 38/50
# 63/63 - 35s - loss: 0.7190 - accuracy: 0.7455 - val_loss: 1.5260 - val_accuracy: 0.3846 - 35s/epoch - 561ms/step
# Epoch 39/50
# 63/63 - 35s - loss: 0.6623 - accuracy: 0.7575 - val_loss: 1.5725 - val_accuracy: 0.4231 - 35s/epoch - 558ms/step
# Epoch 40/50
# 63/63 - 35s - loss: 0.6861 - accuracy: 0.7475 - val_loss: 1.4330 - val_accuracy: 0.4423 - 35s/epoch - 560ms/step
# Epoch 41/50
# 63/63 - 35s - loss: 0.6338 - accuracy: 0.7635 - val_loss: 1.5253 - val_accuracy: 0.4038 - 35s/epoch - 560ms/step
# Epoch 42/50
# 63/63 - 35s - loss: 0.6667 - accuracy: 0.7515 - val_loss: 1.6053 - val_accuracy: 0.4423 - 35s/epoch - 562ms/step
# Epoch 43/50
# 63/63 - 35s - loss: 0.5832 - accuracy: 0.7956 - val_loss: 1.4436 - val_accuracy: 0.5000 - 35s/epoch - 560ms/step
# Epoch 44/50
# 63/63 - 35s - loss: 0.6532 - accuracy: 0.7776 - val_loss: 1.5429 - val_accuracy: 0.3846 - 35s/epoch - 561ms/step
# Epoch 45/50
# 63/63 - 35s - loss: 0.5767 - accuracy: 0.7976 - val_loss: 1.6109 - val_accuracy: 0.4038 - 35s/epoch - 560ms/step
# Epoch 46/50
# 63/63 - 35s - loss: 0.5454 - accuracy: 0.8116 - val_loss: 1.9193 - val_accuracy: 0.4231 - 35s/epoch - 560ms/step
# Epoch 47/50
# 63/63 - 35s - loss: 0.5237 - accuracy: 0.7756 - val_loss: 1.4083 - val_accuracy: 0.4423 - 35s/epoch - 560ms/step
# Epoch 48/50
# 63/63 - 35s - loss: 0.4577 - accuracy: 0.8417 - val_loss: 1.6640 - val_accuracy: 0.4423 - 35s/epoch - 557ms/step
# Epoch 49/50
# 63/63 - 35s - loss: 0.4629 - accuracy: 0.8437 - val_loss: 1.7243 - val_accuracy: 0.4038 - 35s/epoch - 556ms/step
# Epoch 50/50
# 63/63 - 35s - loss: 0.4875 - accuracy: 0.8236 - val_loss: 1.7653 - val_accuracy: 0.4615 - 35s/epoch - 554ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
