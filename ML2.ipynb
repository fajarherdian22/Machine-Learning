# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/citrus.csv')

# %%
df.head(10000)
# Out:
#      name  diameter  weight  red  green  blue
# 0       0      2.96   86.76  172     85     2
# 1       0      3.91   88.05  166     78     3
# 2       0      4.42   95.17  156     81     2
# 3       0      4.47   95.60  163     81     4
# 4       0      4.48   95.76  161     72     9
# ...   ...       ...     ...  ...    ...   ...
# 9995    1     15.35  253.89  149     77    20
# 9996    1     15.41  254.67  148     68     7
# 9997    1     15.59  256.50  168     82    20
# 9998    1     15.92  260.14  142     72    11
# 9999    1     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %% [markdown]
# **MELIHAT INFORMASI DATAFRAME**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10000 non-null  object
#  1   diameter  10000 non-null  float64
#  2   weight    10000 non-null  float64
#  3   red       10000 non-null  int64
#  4   green     10000 non-null  int64
#  5   blue      10000 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 468.9+ KB

# %% [markdown]
# **MENGUBAH TEXT MENJADI NUMERIK**

# %%
df.name[df.name == 'orange'] = 0
df.name[df.name == 'grapefruit'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **MENGUBAH VALUE**

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[0, 2.96, 86.76, 172, 85, 2],
#        [0, 3.91, 88.05, 166, 78, 3],
#        [0, 4.42, 95.17, 156, 81, 2],
#        ...,
#        [1, 15.59, 256.5, 168, 82, 20],
#        [1, 15.92, 260.14, 142, 72, 11],
#        [1, 16.45, 261.51, 152, 74, 2]], dtype=object)

# %% [markdown]
# **MENGAMBIL KOLOM 1 SAMPAI 6 KARENA ITU YANG BERISI ATRIBUT**

# %%
X = dataset[:,1:6]

# %%
y = dataset[:,0]

# %% [markdown]
# **PROSES NORMALISASI DATAFRAME**

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.        , 0.        , 0.74025974, 0.63529412, 0.        ],
#        [0.07042254, 0.00738197, 0.66233766, 0.55294118, 0.01851852],
#        [0.10822832, 0.04812589, 0.53246753, 0.58823529, 0.        ],
#        ...,
#        [0.93624907, 0.97133047, 0.68831169, 0.6       , 0.33333333],
#        [0.96071164, 0.99216023, 0.35064935, 0.48235294, 0.16666667],
#        [1.        , 1.        , 0.48051948, 0.50588235, 0.        ]])

# %% [markdown]
# **MELAKUKAN PELATIHAN DAN PENGUJIAN**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test, = train_test_split(X_scale, y, test_size=0.3)

# %% [markdown]
# **MENGUBAH LABEL MENJADI TIPE DATA BOLEAN FLOAT 32, KARENA MENGUBAH NILAI PADA KOLOM NAME**

# %%
import numpy as np

Y_train = Y_train.astype(np.float32)
Y_test = Y_test.astype(np.float32)

# %% [markdown]
# **MEMBANGUN MODEL**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# **MEMBUAT 3 LAYER**

# %%
model = Sequential([
                    Dense(32, activation='relu', input_shape=(5,)),
                    Dense(32, activation='relu'),
                    Dense(1, activation='sigmoid'),])

# %% [markdown]
# **MENAMBAHKAN PARAMETER AKURASI**

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# **MELAKUKAN PELATIHAN MODEL**

# %%
model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 2s 3ms/step - loss: 0.6426 - accuracy: 0.7426
# Epoch 2/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.5873 - accuracy: 0.9021
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5092 - accuracy: 0.9147
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4188 - accuracy: 0.9217
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3366 - accuracy: 0.9259
# Epoch 6/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.2774 - accuracy: 0.9284
# Epoch 7/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.2406 - accuracy: 0.9286
# Epoch 8/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.2181 - accuracy: 0.9290
# Epoch 9/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2043 - accuracy: 0.9289
# Epoch 10/100
# ...

# %% [markdown]
# **MELAKUKAN EVALUASI**

# %%
model.evaluate(X_test, Y_test)
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9220
# [0.17970755696296692, 0.921999990940094]
